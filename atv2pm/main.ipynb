# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quantstats as qs
from core.dataloader import load_prices_from_csv
from core.engine import walk_forward_backtest
from reports.summary import plot_performance

# %%
# load dataset
filepath = "data/prices.csv"
prices = load_prices_from_csv(filepath)
print(prices.head())
# Out:
#                  AAPL     AMZN       GOOG       MSFT
# Date
# 2015-01-02  24.320436  15.4260  26.045292  40.072136
# 2015-01-05  23.635279  15.1095  25.502361  39.703640
# 2015-01-06  23.637518  14.7645  24.911291  39.120892
# 2015-01-07  23.968962  14.9210  24.868610  39.617935
# 2015-01-08  24.889898  15.0230  24.947021  40.783432

# %%
# run backtest
returns = walk_forward_backtest(prices)

# %%
# plot performance
returns.plot(title="Cumulative Portfolio Value", figsize=(12, 6))
plt.grid()
plt.show()

# %%
# Save Performance CSV
returns.to_csv("data/backtest_results.csv")

# %%
# Performance Metrics
qs.reports.metrics(returns, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2015-04-07
# End Period                 2022-12-30
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          263.86%
# CAGR﹪                     12.22%
#
# Sharpe                     0.47
# Prob. Sharpe Ratio         89.5%
# Smart Sharpe               0.35
# Sortino                    0.67
# Smart Sortino              0.5
# Sortino/√2                 0.47
# Smart Sortino/√2           0.35
# Omega                      1.16
#
# Max Drawdown               -169.05%
# Longest DD Days            2149
# Volatility (ann.)          157.28%
# Calmar                     0.07
# Skew                       -1.9
# Kurtosis                   93.68
#
# Expected Daily %           0.07%
# Expected Monthly %         1.4%
# Expected Yearly %          17.52%
# Kelly Criterion            7.15%
# Risk of Ruin               0.0%
# ...
